# %%
def detect_cycle(head):
   
   slow = fast = head
   while fast and fast.next:
      slow = slow.next
      fast = fast.next.next
      if slow == fast: return True
   return False

# %%
def find_duplicate(nums):

    # pos = [False] * len(nums) 
    # for x in nums:
    #   if pos[x]: return x
    #   pos[x] = x
    # return 0
    while True: # this is same as a cycle in LL. How and why?
        slow = nums[slow]
        fast = nums[nums[fast]]
        if slow == fast: break;

    slow2 = 0
    while True:
        slow2 = nums[slow2]
        slow = nums[slow]
        if slow2 == slow: return slow2
    return 0
